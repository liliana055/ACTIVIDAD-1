# %% [markdown]
# <a href="https://colab.research.google.com/github/liliana055/ACTIVIDAD-1/blob/main/Ejercicio1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola Colab") #celda de código
# Out:
# Hola Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ruta = "/content/drive/MyDrive/Colab Notebooks"

# %%
import functools
import time

#Simulación de datos de temperatura
temperaturas = [("CDMX", 26), ("Monterrey", 34), ("Toluca", 19), ("Cancún", 38), ("Guadalajara", 33), ("Tijuana", 28)]

#Generador de datos de temperatura
def leer_temperaturas():
    for ciudad, temperatura in temperaturas:
        yield (ciudad, temperatura)

#Decorador para llamar a las funciones
def auditar_funcion(func):
    contador = 0

    def wrapper(*args, **kwargs):
        nonlocal contador
        contador += 1
        print(f"Ejecutando función: {func.__name__} - Llamada#{contador}")
        resultado = func(*args, **kwargs)
        return resultado

    return wrapper

# Función que filtra temperaturas altas
def filtrar_temperaturas():
    return filter(lambda x: x[1] > 30, temperaturas)

# Función que transforma las tuplas a formato de alerta
@auditar_funcion
def transformar_alertas():
    temperaturas_filtradas = filtrar_temperaturas()
    return list(map(lambda x: f"Alerta de calor en {x[0]}: {x[1]}°C", temperaturas_filtradas))

#Función que ordena las alertas por temperatura de mayor a menor
@auditar_funcion
def ordenar_alertas():
    alertas_transformadas = transformar_alertas()
    return sorted(alertas_transformadas, key=lambda x: int(x.split(":")[1][:-2]), reverse=True)

#Función que calcula el promedio de las diferentes temperaturas ya filtradas
def calcular_promedio():
    temperaturas_filtradas = filtrar_temperaturas()
    temperaturas = list(temperaturas_filtradas)
    total = functools.reduce(lambda acc, x: acc + x[1], temperaturas, 0)
    return total / len(temperaturas) if temperaturas else 0

#Ejecucción de las funciones
if __name__ == "__main__":
     #Imprimir la lista ordenada de alertas
     alertas_ordenadas = ordenar_alertas()
     print("\nAlertas de calor ordenadas:")
     for alerta in alertas_ordenadas:
        print(alerta)

     #Calcular y mostrar el promedio de temperaturas
     promedio = calcular_promedio()
     print(f"\nTemperatura promedio de alertas: {promedio:.1f}°C")
# Out:
# Ejecutando función: ordenar_alertas - Llamada#1
# Ejecutando función: transformar_alertas - Llamada#1
#
# Alertas de calor ordenadas:
# Alerta de calor en Cancún: 38°C
# Alerta de calor en Monterrey: 34°C
# Alerta de calor en Guadalajara: 33°C
#
# Temperatura promedio de alertas: 35.0°C
