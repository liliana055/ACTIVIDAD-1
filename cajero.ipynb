# %%
# Variables para contar billetes en inventario
billetes_1000 = 10
billetes_500 = 10
billetes_200 = 10
billetes_100 = 10
billetes_50 = 10

# Variables para billetes a entregar
entregar_1000 = 0
entregar_500 = 0
entregar_200 = 0
entregar_100 = 0
entregar_50 = 0
monto_restante = 0

# Iniciar el sistema
print("\n--- Dispensadora de Billetes ---")

# Solicitar monto
print("\nIngrese el monto a retirar (0 para salir): ")
entrada = input()
monto = int(entrada)

if monto == 0:
    print("Saliendo...")
else:
    monto_restante = monto

    # Lógica para entregar billetes de mayor a menor denominación
    for denom, billetes in [(1000, billetes_1000), (500, billetes_500), (200, billetes_200), 
                            (100, billetes_100), (50, billetes_50)]:
        billetes_entregar = min(monto_restante // denom, billetes)
        monto_restante -= billetes_entregar * denom

        # Asignar a la variable correspondiente para entregar
        if denom == 1000:
            entregar_1000 = billetes_entregar
        elif denom == 500:
            entregar_500 = billetes_entregar
        elif denom == 200:
            entregar_200 = billetes_entregar
        elif denom == 100:
            entregar_100 = billetes_entregar
        elif denom == 50:
            entregar_50 = billetes_entregar

    if monto_restante > 0:
        print("\nNo hay suficientes billetes para satisfacer el monto solicitado.")
    else:
        print("\n--- Billetes a entregar ---")
        print(f"Billetes de 1000: {entregar_1000}")
        print(f"Billetes de 500: {entregar_500}")
        print(f"Billetes de 200: {entregar_200}")
        print(f"Billetes de 100: {entregar_100}")
        print(f"Billetes de 50: {entregar_50}")
        print(f"Monto restante: {monto_restante}")
# Out:
# --- Dispensadora de Billetes ---
#
# Ingrese el monto a retirar (0 para salir):
#
# No hay suficientes billetes para satisfacer el monto solicitado.
